# %% [markdown]
# <a href="https://colab.research.google.com/github/minchen-wisc/FWE458_Spring2024/blob/main/Lecture_6_Basics_in_Math%2C_Statistics_and_Data_Analysis_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basic Python, without importing any external packages, provides a limited set of functions for more advanced mathematics directly in its core syntax and built-in functions.

# %%
# even some commonly used functions are not available
sin(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-aee041667bb1> in <cell line: 2>()
#       1 # even some commonly used functions are not available
# ----> 2 sin(10)
#
# NameError: name 'sin' is not defined

# %% [markdown]
# ## Advanced mathematics in Python programming involves leveraging specialized libraries that extend Python's built-in mathematical capabilities. Python, with libraries like **numpy**, **scipy**, and **sympy**, becomes a powerful environment for performing complex mathematical operations, solving equations, and working with symbolic mathematics.

# %% [markdown]
# ### 1. Understanding Packages
# A package in Python is a directory of Python scripts, each script is a module that can define functions, classes, and variables. These modules can also include runnable code. Using packages enables you to organize your Python code in a modular and reusable way.
#
# **What is a Package?**
#    - A package is essentially a way to organize related modules into a single directory hierarchy. This includes not just code, but also metadata about the package, like its name, version, and dependencies.
#
# **Installing Packages**
#    - Use `pip`, Python's package installer, to download and install packages from the Python Package Index (PyPI).
#    - Example:
#      ```bash
#      pip install numpy
#      ```
#    - This command installs the `numpy` package, which is a powerful package for numerical computations. Note: `numpy` is usually pre-installed.
#    - In colab, use
#    ```python
#      !pip install numpy
#      ```
#
# **Importing a Package**
#    - Once installed, you can use `import` to bring a package's functionalities into your script.
#    - Example:
#      ```python
#      import numpy as np
#      ```
#    - This command imports the `numpy` package and aliases it as `np` for convenience.
#
#    Importing a package in Python is a fundamental concept that enables you to use code from one module or package in another. When you import a package, Python searches for the specified package or module in its list of known locations and, if found, makes its contents (functions, classes, variables) available in your current namespace. Here's a more detailed look at how importing works and some advanced aspects of it:
#
#    - Basic Import Syntax
#
#     **Importing a Module or Package**: Use the `import` statement to import a module or package.
#     ```python
#     import math
#     print(math.sqrt(16))  # Accessing the sqrt function from the math module
#     ```
#
#     **Importing with Aliasing**: Use the `as` keyword to alias a module for convenience.
#     ```python
#     import numpy as np
#     arr = np.array([1, 2, 3])  # Using the alias np for numpy
#     ```
#
#     **Importing Specific Objects**: Use the `from ... import ...` syntax to import specific functions, classes, or variables.
#     ```python
#     from math import sqrt
#     print(sqrt(16))  # Directly using sqrt without prefixing it with math.
#     ```
#
# **Finding Packages**
#    - Guide on how to find packages. PyPI (Python Package Index) is the primary repository, and packages can be searched through its website or via `pip search`.
#
# **Reading Documentation**
#    - Stress the importance of reading a package's documentation before using it. Documentation often includes installation instructions, usage examples, and API references.
#
#
# ### 2. Introduction to `numpy` for Numerical Computations
#
# **Objective**: Utilize `numpy` for efficient array operations and mathematical computations.
#
# - **Array Operations**:
#   ```python
#   import numpy as np
#
#   # Vector addition
#   v1 = np.array([1, 2, 3])
#   v2 = np.array([4, 5, 6])
#   print("Vector addition:", v1 + v2)
#
#   # Matrix multiplication
#   A = np.array([[1, 2], [3, 4]])
#   B = np.array([[2, 0], [1, 3]])
#   print("Matrix multiplication:\n", np.dot(A, B))
#   ```
#
# - **Mathematical Functions**:
#   ```python
#   x = np.linspace(0, 2*np.pi, 100)  # 100 points from 0 to 2π
#   y = np.sin(x)  # Apply sin() function to each element
#   ```
#
# ### 3. Exploring `scipy` for Advanced Mathematical and Scientific Computations
#
# **Objective**: Apply `scipy` for tasks like optimization, linear algebra, and statistical analysis.
#
# - **Optimization Example**:
#   ```python
#   from scipy.optimize import minimize
#
#   # Define a simple quadratic function
#   def f(x): return x**2 + 10*np.sin(x)
#
#   # Find the minimum
#   result = minimize(f, x0=0)
#   print("Minimum of f(x):", result.x)
#   ```
#
# - **Linear Algebra Example**:
#   ```python
#   from scipy import linalg
#
#   # Solve Ax = b
#   A = np.array([[1, 2], [3, 4]])
#   b = np.array([1, 4])
#   x = linalg.solve(A, b)
#   print("Solution to Ax = b:", x)
#   ```
#
# ### 4. Using `sympy` for Symbolic Mathematics
#
# **Objective**: Perform algebraic manipulations, solve equations symbolically, and perform calculus operations using `sympy`.
#
# - **Solve Equations**:
#   ```python
#   from sympy import symbols, Eq, solve
#
#   x, y = symbols('x y')
#   equation = Eq(2*x + y, 1)
#   solution = solve(equation, x)
#   print("Solution for x:", solution)
#   ```
#
# - **Calculus Operations**:
#   ```python
#   from sympy import diff, integrate, sin
#
#   # Differentiation
#   print("Derivative of sin(x):", diff(sin(x), x))
#
#   # Definite integration
#   print("Integral of sin(x) from 0 to pi:", integrate(sin(x), (x, 0, np.pi)))
#   ```
#
# ### 5. Using `numpy` for reading data

# %%
# mounting drive
from google.colab import drive
drive.mount('/content/drive')

filedir = '/content/drive/MyDrive/Teaching/FWE458_Spring2025/Lec6/'

import numpy as np
# load data from a txt file
fname = filedir + "MaunaLoaCO2_monthly.txt"
print(fname)
A = np.loadtxt(fname)
print(A)

import matplotlib.pyplot as plt
plt.plot(A[:,2], A[:,3], 'o')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Teaching/FWE458_Spring2025/Lec6/MaunaLoaCO2_monthly.txt
# [[ 1.9580000e+03  3.0000000e+00  1.9582027e+03 ...  3.1443000e+02
#   -1.0000000e+00 -9.9900000e+00]
#  [ 1.9580000e+03  4.0000000e+00  1.9582877e+03 ...  3.1516000e+02
#   -1.0000000e+00 -9.9900000e+00]
#  [ 1.9580000e+03  5.0000000e+00  1.9583699e+03 ...  3.1471000e+02
#   -1.0000000e+00 -9.9900000e+00]
#  ...
#  [ 2.0210000e+03  1.1000000e+01  2.0218750e+03 ...  4.1707000e+02
#    3.0000000e+01  3.6000000e-01]
#  [ 2.0210000e+03  1.2000000e+01  2.0219583e+03 ...  4.1744000e+02
#    2.8000000e+01  4.8000000e-01]
#  [ 2.0220000e+03  1.0000000e+00  2.0220417e+03 ...  4.1787000e+02
#    2.9000000e+01  7.5000000e-01]]

# %%
# subset data
fname = filedir + "MaunaLoaCO2_monthly.txt"
A = np.loadtxt(fname)
A.shape

B = A[A[:,2]>2015, :]
B.shape

import matplotlib.pyplot as plt
plt.plot(B[:,2], B[:,3], '-o')

# %% [markdown]
# ### 6. Using `pandas` for reading data
#  Pandas is an open-source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language. It's built on top of the NumPy library and offers various functions and capabilities to make data manipulation and analysis fast and straightforward in Python. Here's an introduction to some of the core features and functionalities of pandas:
#
# #### Core Data Structures: Series and DataFrame
#
# **Series**: A one-dimensional labeled array capable of holding any data type (integers, strings, floating-point numbers, Python objects, etc.). The axis labels are collectively referred to as the index.
#    ```python
#    import pandas as pd
#
#    data = pd.Series([1, 3, 5, 7, 9])
#    print(data)
#    ```
#
# **DataFrame**: A two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns). It's essentially a dictionary-like container for Series objects.
#    ```python
#    df = pd.DataFrame({
#        'A': [1, 2, 3, 4],
#        'B': ['a', 'b', 'c', 'd']
#    })
#    print(df)
#    ```
#
# #### Key Features of Pandas
#
# - **Handling Missing Data**: Pandas is equipped to handle missing data using methods like `isnull()`, `dropna()`, and `fillna()` among others.
# - **Data Alignment**: Automatic and explicit data alignment. This is especially useful when dealing with missing values in time series data.
# - **Reshaping and Pivoting**: Easily reshape and pivot data sets. Methods like `pivot_table`, `stack`, and `unstack` are handy for reshaping data frames.
# - **Label-based Slicing, Indexing, and Subsetting of large data sets**: Columns can be extracted by name using `df['column_name']` and rows by index position using `df.loc[index]`.
# - **Data Filtering**: Apply conditional logic to data columns for filtering rows or showing specific data.
# - **Group By functionality**: Split data into groups based on some criteria and apply a function to each group independently, similar to the SQL group by statement.
# - **Merging and Joining**: Easily combine and merge data sets using the `merge` and `join` methods.
# - **Time Series functionality**: Extensive support for working with dates, times, and time-indexed data. This includes generating date ranges, shifting and lagging data, and time zone handling.
#
# #### Getting Started with Pandas
#
# To use pandas, you first need to install it. This can be done via pip:
#
# ```bash
# pip install pandas
# ```
#
# Here's a simple example of how to create a DataFrame and perform a basic operation:
#
# ```python
# import pandas as pd
#
# # Create a DataFrame
# data = {'Name': ['John', 'Anna', 'Peter', 'Linda'],
#         'Location': ['New York', 'Paris', 'Berlin', 'London'],
#         'Age': [24, 13, 53, 33]
#        }
# df = pd.DataFrame(data)
#
# # View the DataFrame
# print(df)
#
# # Basic operation: Get summary statistics
# print(df.describe())
# ```
#
# #### Why Use Pandas?
#
# Pandas simplifies the process of data manipulation and analysis in Python. It is designed to work with "relational" or "labeled" data, making it a perfect tool for real-world data analysis that often involves complex manipulation and preparation of data. Whether you're cleaning data, transforming it, or analyzing it, pandas provides the functionality and flexibility to make these tasks intuitive and efficient.
#
# Pandas is widely used in academic and commercial domains, including finance, neuroscience, economics, statistics, advertising, web analytics, and more. With its powerful data structures for efficient data manipulation and its easy-to-use data analysis tools, pandas is a cornerstone of the Python data science stack.

# %%
# Pandas
import pandas as pd

fname = filedir + "MaunaLoaCO2_monthly_sitename.csv"
DF = pd.read_csv(fname)

print(DF)
# Out:
#      Year  Month  Decimal_date  Monthly_average  deseasonalized  numofdays  \
# 0    1958      3     1958.2027           315.70          314.43         -1
# 1    1958      4     1958.2877           317.45          315.16         -1
# 2    1958      5     1958.3699           317.51          314.71         -1
# 3    1958      6     1958.4548           317.24          315.14         -1
# 4    1958      7     1958.5370           315.86          315.18         -1
# ..    ...    ...           ...              ...             ...        ...
# 762  2021      9     2021.7083           413.30          416.90         27
# 763  2021     10     2021.7917           413.93          417.30         29
# 764  2021     11     2021.8750           415.01          417.07         30
# 765  2021     12     2021.9583           416.71          417.44         28
# 766  2022      1     2022.0417           418.19          417.87         29
#
#      stdofdays      site
# 0        -9.99  MaunaLoa
# 1        -9.99  MaunaLoa
# 2        -9.99  MaunaLoa
# 3        -9.99  MaunaLoa
# 4        -9.99  MaunaLoa
# ..         ...       ...
# 762       0.29  MaunaLoa
# 763       0.35  MaunaLoa
# 764       0.36  MaunaLoa
# 765       0.48  MaunaLoa
# 766       0.75  MaunaLoa
#
# [767 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(DF[["Decimal_date"]], DF[["Monthly_average"]], 'o')
plt.plot(DF["Decimal_date"], DF["Monthly_average"], 'o')
plt.plot(DF.Decimal_date, DF.Monthly_average, 'o')

# note the difference between DF[["Decimal_date"]] and DF["Decimal_date"]
print(type(DF[["Decimal_date"]]))
print(type(DF["Decimal_date"]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
# Select Data Using Location Index (.iloc)
# use .iloc to select individual rows and
# columns or a series of rows and columns
# by providing the range (i.e. start and
# stop locations along the rows and columns)
# that you want to select.

print(DF.iloc[0,0])

import matplotlib.pyplot as plt
plt.plot(DF.iloc[:, 2], DF.iloc[:, 3], 'o')
# Out:
# 1958

# %%
yi = DF.set_index("Year")
yi
# Out:
#       Month  Decimal_date  Monthly_average  deseasonalized  numofdays  \
# Year
# 1958      3     1958.2027           315.70          314.43         -1
# 1958      4     1958.2877           317.45          315.16         -1
# 1958      5     1958.3699           317.51          314.71         -1
# 1958      6     1958.4548           317.24          315.14         -1
# 1958      7     1958.5370           315.86          315.18         -1
# ...     ...           ...              ...             ...        ...
# 2021      9     2021.7083           413.30          416.90         27
# 2021     10     2021.7917           413.93          417.30         29
# 2021     11     2021.8750           415.01          417.07         30
# 2021     12     2021.9583           416.71          417.44         28
# 2022      1     2022.0417           418.19          417.87         29
#
#       stdofdays      site
# Year
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# ...         ...       ...
# 2021       0.29  MaunaLoa
# 2021       0.35  MaunaLoa
# 2021       0.36  MaunaLoa
# 2021       0.48  MaunaLoa
# 2022       0.75  MaunaLoa
#
# [767 rows x 7 columns]

# %%
yi.loc[[1958]]
# Out:
#       Month  Decimal_date  Monthly_average  deseasonalized  numofdays  \
# Year
# 1958      3     1958.2027           315.70          314.43         -1
# 1958      4     1958.2877           317.45          315.16         -1
# 1958      5     1958.3699           317.51          314.71         -1
# 1958      6     1958.4548           317.24          315.14         -1
# 1958      7     1958.5370           315.86          315.18         -1
# 1958      8     1958.6219           314.93          316.18         -1
# 1958      9     1958.7068           313.20          316.08         -1
# 1958     10     1958.7890           312.43          315.41         -1
# 1958     11     1958.8740           313.33          315.20         -1
# 1958     12     1958.9562           314.67          315.43         -1
#
#       stdofdays      site
# Year
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa
# 1958      -9.99  MaunaLoa

# %%
DF
DF.loc[(DF["Year"] == 1958), ["Monthly_average", "site"]]
# Out:
#    Monthly_average      site
# 0           315.70  MaunaLoa
# 1           317.45  MaunaLoa
# 2           317.51  MaunaLoa
# 3           317.24  MaunaLoa
# 4           315.86  MaunaLoa
# 5           314.93  MaunaLoa
# 6           313.20  MaunaLoa
# 7           312.43  MaunaLoa
# 8           313.33  MaunaLoa
# 9           314.67  MaunaLoa

# %%
# Check for missing values in each column
DF.isnull().sum()
# Out:
# Year               0
# Month              0
# Decimal_date       0
# Monthly_average    0
# deseasonalized     0
# numofdays          0
# stdofdays          0
# site               0
# dtype: int64

# %%
# replace a certain element's value
import numpy as np
DF.loc[2, 'Year'] = np.nan
DF
DF.isnull().sum()
# Out:
# Year               1
# Month              0
# Decimal_date       0
# Monthly_average    0
# deseasonalized     0
# numofdays          0
# stdofdays          0
# site               0
# dtype: int64

# %%
# If necessary, fill missing values using forward fill method
# This propagates the last valid observation forward to fill gaps
DF.fillna(method='ffill', inplace=True)
DF
# Out:
# <ipython-input-29-eb8e20c18d4b>:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   DF.fillna(method='ffill', inplace=True)
#        Year  Month  Decimal_date  Monthly_average  deseasonalized  numofdays  \
# 0    1958.0      3     1958.2027           315.70          314.43         -1
# 1    1958.0      4     1958.2877           317.45          315.16         -1
# 2    1958.0      5     1958.3699           317.51          314.71         -1
# 3    1958.0      6     1958.4548           317.24          315.14         -1
# 4    1958.0      7     1958.5370           315.86          315.18         -1
# ..      ...    ...           ...              ...             ...        ...
# 762  2021.0      9     2021.7083           413.30          416.90         27
# 763  2021.0     10     2021.7917           413.93          417.30         29
# 764  2021.0     11     2021.8750           415.01          417.07         30
# 765  2021.0     12     2021.9583           416.71          417.44         28
# 766  2022.0      1     2022.0417           418.19          417.87         29
#
#      stdofdays      site
# 0        -9.99  MaunaLoa
# 1        -9.99  MaunaLoa
# 2        -9.99  MaunaLoa
# 3        -9.99  MaunaLoa
# 4        -9.99  MaunaLoa
# ..         ...       ...
# 762       0.29  MaunaLoa
# 763       0.35  MaunaLoa
# 764       0.36  MaunaLoa
# 765       0.48  MaunaLoa
# 766       0.75  MaunaLoa
#
# [767 rows x 8 columns]

# %%
DF[["Year"]] = pd.NA
# Replace invalid values (-9.99) with NaN to mark them as missing
DF.replace(pd.NA, 9999, inplace=True)
DF
# Out:
# <ipython-input-35-4e222d5a1a6f>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   DF.replace(pd.NA, 9999, inplace=True)
#      Year  Month  Decimal_date  Monthly_average  deseasonalized  numofdays  \
# 0    9999      3     1958.2027           315.70          314.43         -1
# 1    9999      4     1958.2877           317.45          315.16         -1
# 2    9999      5     1958.3699           317.51          314.71         -1
# 3    9999      6     1958.4548           317.24          315.14         -1
# 4    9999      7     1958.5370           315.86          315.18         -1
# ..    ...    ...           ...              ...             ...        ...
# 762  9999      9     2021.7083           413.30          416.90         27
# 763  9999     10     2021.7917           413.93          417.30         29
# 764  9999     11     2021.8750           415.01          417.07         30
# 765  9999     12     2021.9583           416.71          417.44         28
# 766  9999      1     2022.0417           418.19          417.87         29
#
#      stdofdays      site
# 0      9999.00  MaunaLoa
# 1      9999.00  MaunaLoa
# 2      9999.00  MaunaLoa
# 3      9999.00  MaunaLoa
# 4      9999.00  MaunaLoa
# ..         ...       ...
# 762       0.29  MaunaLoa
# 763       0.35  MaunaLoa
# 764       0.36  MaunaLoa
# 765       0.48  MaunaLoa
# 766       0.75  MaunaLoa
#
# [767 rows x 8 columns]

# %%
# Drop an unnecessary column ('site') from the dataset
DF.drop(columns=['site'], inplace=True)

# Drop rows with any missing values to ensure data consistency
DF.dropna(inplace=True)

# %%
# Rename 'Monthly_average' to a more readable 'CO2_Avg'
DF.rename(columns={'Monthly_average': 'CO2_Avg'}, inplace=True)

# Reorder columns for better readability
DF = DF[['Year', 'Month', 'Decimal_date', 'CO2_Avg', 'deseasonalized', 'numofdays', 'stdofdays']]

# Create a new column 'Date' by combining 'Year' and 'Month'
DF['Date'] = pd.to_datetime(DF[['Year', 'Month']].assign(day=1))

# Set 'Date' as the index for better time-series analysis
DF.set_index('Date', inplace=True)

DF
# Out:
#             Year  Month  Decimal_date  CO2_Avg  deseasonalized  numofdays  \
# Date
# 1958-03-01  1958      3     1958.2027   315.70          314.43         -1
# 1958-04-01  1958      4     1958.2877   317.45          315.16         -1
# 1958-05-01  1958      5     1958.3699   317.51          314.71         -1
# 1958-06-01  1958      6     1958.4548   317.24          315.14         -1
# 1958-07-01  1958      7     1958.5370   315.86          315.18         -1
# ...          ...    ...           ...      ...             ...        ...
# 2021-09-01  2021      9     2021.7083   413.30          416.90         27
# 2021-10-01  2021     10     2021.7917   413.93          417.30         29
# 2021-11-01  2021     11     2021.8750   415.01          417.07         30
# 2021-12-01  2021     12     2021.9583   416.71          417.44         28
# 2022-01-01  2022      1     2022.0417   418.19          417.87         29
#
#             stdofdays
# Date
# 1958-03-01      -9.99
# 1958-04-01      -9.99
# 1958-05-01      -9.99
# 1958-06-01      -9.99
# 1958-07-01      -9.99
# ...               ...
# 2021-09-01       0.29
# 2021-10-01       0.35
# 2021-11-01       0.36
# 2021-12-01       0.48
# 2022-01-01       0.75
#
# [767 rows x 7 columns]

# %%
# Select data for a specific year (e.g., 2020)
DF_2020 = DF[DF['Year'] == 2020]

# Select rows where CO2 concentration is greater than 400 ppm using loc
DF_loc = DF.loc[DF['CO2_Avg'] > 400, ['Year', 'Month', 'CO2_Avg']]

# Select a subset of rows by position using iloc
DF_iloc = DF.iloc[10:20, :]  # Retrieves rows 10 to 19 (zero-based index)

# %%
# Concatenate two DataFrames vertically to merge data from different years
DF_combined = pd.concat([DF_2020, DF[DF['Year'] == 2021]])

# %%
# Generate summary statistics for all numerical columns
DF.describe()

# Calculate specific statistics
mean_co2 = DF['CO2_Avg'].mean()  # Mean CO2 concentration
median_co2 = DF['CO2_Avg'].median()  # Median CO2 concentration
std_co2 = DF['CO2_Avg'].std()  # Standard deviation of CO2 concentration

# Compute CO2 anomaly by subtracting the mean CO2 concentration from each value
DF['CO2_Anomaly'] = DF['CO2_Avg'] - DF['CO2_Avg'].mean()

DF
# Out:
#             Year  Month  Decimal_date  CO2_Avg  deseasonalized  numofdays  \
# Date
# 1958-03-01  1958      3     1958.2027   315.70          314.43         -1
# 1958-04-01  1958      4     1958.2877   317.45          315.16         -1
# 1958-05-01  1958      5     1958.3699   317.51          314.71         -1
# 1958-06-01  1958      6     1958.4548   317.24          315.14         -1
# 1958-07-01  1958      7     1958.5370   315.86          315.18         -1
# ...          ...    ...           ...      ...             ...        ...
# 2021-09-01  2021      9     2021.7083   413.30          416.90         27
# 2021-10-01  2021     10     2021.7917   413.93          417.30         29
# 2021-11-01  2021     11     2021.8750   415.01          417.07         30
# 2021-12-01  2021     12     2021.9583   416.71          417.44         28
# 2022-01-01  2022      1     2022.0417   418.19          417.87         29
#
#             stdofdays  CO2_Anomaly
# Date
# 1958-03-01      -9.99   -41.169817
# 1958-04-01      -9.99   -39.419817
# 1958-05-01      -9.99   -39.359817
# 1958-06-01      -9.99   -39.629817
# 1958-07-01      -9.99   -41.009817
# ...               ...          ...
# 2021-09-01       0.29    56.430183
# 2021-10-01       0.35    57.060183
# 2021-11-01       0.36    58.140183
# 2021-12-01       0.48    59.840183
# 2022-01-01       0.75    61.320183
#
# [767 rows x 8 columns]

# %%
# Compute the mean CO2 concentration for each year
DF_yearly = DF.groupby('Year')['CO2_Avg'].mean().reset_index()

DF_yearly
# Out:
#     Year     CO2_Avg
# 0   1958  315.232000
# 1   1959  315.980833
# 2   1960  316.910000
# 3   1961  317.644167
# 4   1962  318.454167
# ..   ...         ...
# 60  2018  408.715000
# 61  2019  411.654167
# 62  2020  414.238333
# 63  2021  416.450833
# 64  2022  418.190000
#
# [65 rows x 2 columns]

# %%
# Convert CO2_Avg values into categorical labels based on threshold
def categorize_co2(value):
    if value < 350:
        return 'Low'
    elif value < 400:
        return 'Medium'
    else:
        return 'High'

# Apply the function to create a new categorical column
DF['CO2_Category'] = DF['CO2_Avg'].apply(categorize_co2)

DF
# Out:
#             Year  Month  Decimal_date  CO2_Avg  deseasonalized  numofdays  \
# Date
# 1958-03-01  1958      3     1958.2027   315.70          314.43         -1
# 1958-04-01  1958      4     1958.2877   317.45          315.16         -1
# 1958-05-01  1958      5     1958.3699   317.51          314.71         -1
# 1958-06-01  1958      6     1958.4548   317.24          315.14         -1
# 1958-07-01  1958      7     1958.5370   315.86          315.18         -1
# ...          ...    ...           ...      ...             ...        ...
# 2021-09-01  2021      9     2021.7083   413.30          416.90         27
# 2021-10-01  2021     10     2021.7917   413.93          417.30         29
# 2021-11-01  2021     11     2021.8750   415.01          417.07         30
# 2021-12-01  2021     12     2021.9583   416.71          417.44         28
# 2022-01-01  2022      1     2022.0417   418.19          417.87         29
#
#             stdofdays  CO2_Anomaly CO2_Category
# Date
# 1958-03-01      -9.99   -41.169817          Low
# 1958-04-01      -9.99   -39.419817          Low
# 1958-05-01      -9.99   -39.359817          Low
# 1958-06-01      -9.99   -39.629817          Low
# 1958-07-01      -9.99   -41.009817          Low
# ...               ...          ...          ...
# 2021-09-01       0.29    56.430183         High
# 2021-10-01       0.35    57.060183         High
# 2021-11-01       0.36    58.140183         High
# 2021-12-01       0.48    59.840183         High
# 2022-01-01       0.75    61.320183         High
#
# [767 rows x 9 columns]
